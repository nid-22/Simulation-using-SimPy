# %% [markdown]
# ### TASK:
# To create a simulation of a container terminal using SimPy
#
# ### Components:
#   - Vessels: Arrive at the terminal with an inter-arrival time following an exponential distribution. Each carries 150 containers.
#   - Berths: Limited to 2 slots where vessels can dock.
#   - Quay Cranes: 2 cranes are available to unload containers from vessels to trucks. Each operation takes 3 minutes per container.
#   - Trucks: 3 trucks transport containers from cranes to the yard, with a round trip taking 6 minutes.
#
# ### Requirements:
#   - Simulation Events: Logging for vessel arrival, berthing, container unloading, and truck movements.

# %%
import simpy
import random
import itertools

# %%
NUM_CONTAINERS_PER_VESSEL = 150 # Each vessel holds 150 containers
VESSEL_INTERVAL = 300           # Mean time between arrivals in minutes
CRANE_UNLOADING_TIME = 3        # Time to unload one container in minutes
TRUCK_TRANSPORT_TIME = 6        # Round trip transport time for a truck in minutes
SIM_TIME = 3000                 # Total simulation time in minutes
RANDOM_SEED = 42

# %%
class Terminal:
    """
    Simulates a container terminal with specified unloading and transport times.
    """
    def __init__(self, env, unload_time, transport_time):
        self.env = env
        self.berths = simpy.Resource(env, 2)
        self.cranes = simpy.Resource(env, 2)
        self.trucks = simpy.Resource(env, 3)
        self.unload_time = unload_time
        self.truck_transport_time = transport_time

    def unload_vessel(self, vessel_name):
        """
        Simulates the unloading of containers from a vessel.
        """
        crane_request = self.cranes.request()
        yield crane_request  # Wait for a crane to become available
        
        # since only 1 crane is used by a vessel, all 150 containers will use the same crane_request
        for container_number in range(1, NUM_CONTAINERS_PER_VESSEL + 1):
            truck_request = self.trucks.request()
            yield truck_request  # Wait for a truck to become available
            
            print(f'{self.env.now:.0f} : {vessel_name} : Crane starts unloading container-{container_number} to truck')
            yield self.env.timeout(self.unload_time)
            
            print(f'{self.env.now:.0f} : {vessel_name} : Truck left with container-{container_number}')
            
            # Start the truck transport process without waiting for it to complete
            self.env.process(self.simulate_transport(vessel_name, container_number, truck_request))
            
        self.cranes.release(crane_request)  # Release the crane

    def simulate_transport(self, vessel_name, container_number, truck_request):
        """
        Simulates the truck's round trip for transporting a container.
        """
        yield self.env.timeout(self.truck_transport_time)
        print(f'{self.env.now:.0f} : {vessel_name} : Truck returned after transporting container-{container_number}')
        self.trucks.release(truck_request)  # Release the truck


def vessel_arrival(env, vessel_name, terminal):
    """
    Processes the arrival and unloading of a vessel at the terminal.
    """
    print(f'{env.now:.0f} : {vessel_name} : Arrived at terminal_ _ _ _ _ _<-\___/')
    with terminal.berths.request() as berth_request:
        yield berth_request  # Wait for berth availability
        print(f'{env.now:.0f} : {vessel_name} : Berthed')
        
        yield env.process(terminal.unload_vessel(vessel_name))
        print(f'{env.now:.0f} : {vessel_name} : Finished unloading and is leaving_ _ _ _ _ \___/->')


def vessel_generator(env, terminal):
    """
    Generates vessels arriving at the terminal.
    """
    vessel_count = itertools.count(1)
    while True:
        t = random.expovariate(1.0 / VESSEL_INTERVAL)
        yield env.timeout(t)
        env.process(vessel_arrival(env, f'Vessel {next(vessel_count)}', terminal))


print('Container Terminal Unload Simulation')
print('-----------------------------------------------------')
print('Time(m) | Vessel |  Action')
print('-----------------------------------------------------')
random.seed(RANDOM_SEED)

env = simpy.Environment()
terminal = Terminal(env, CRANE_UNLOADING_TIME, TRUCK_TRANSPORT_TIME)
env.process(vessel_generator(env, terminal))
env.run(until=SIM_TIME)
# Out:
# Container Terminal Unload Simulation
# -----------------------------------------------------
# Time(m) | Vessel |  Action
# -----------------------------------------------------
# 306 : Vessel 1 : Arrived at terminal_ _ _ _ _ _<-\___/
# 306 : Vessel 1 : Berthed
# 306 : Vessel 1 : Crane starts unloading container-1 to truck
# 309 : Vessel 1 : Truck left with container-1
# 309 : Vessel 1 : Crane starts unloading container-2 to truck
# 312 : Vessel 1 : Truck left with container-2
# 312 : Vessel 1 : Crane starts unloading container-3 to truck
# 314 : Vessel 2 : Arrived at terminal_ _ _ _ _ _<-\___/
# 314 : Vessel 2 : Berthed
# 315 : Vessel 1 : Truck returned after transporting container-1
# 315 : Vessel 1 : Truck left with container-3
# 315 : Vessel 2 : Crane starts unloading container-1 to truck
# 318 : Vessel 1 : Truck returned after transporting container-2
# 318 : Vessel 2 : Truck left with container-1
# 318 : Vessel 1 : Crane starts unloading container-4 to truck
# 321 : Vessel 1 : Truck returned after transporting container-3
# 321 : Vessel 1 : Truck left with container-4
# 321 : Vessel 2 : Crane starts unloading container-2 to truck
# 324 : Vessel 2 : Truck returned after transporting container-1
# 324 : Vessel 2 : Truck left with container-2
# 324 : Vessel 1 : Crane starts unloading container-5 to truck
# 327 : Vessel 1 : Truck returned after transporting container-4
# 327 : Vessel 1 : Truck left with container-5
# 327 : Vessel 2 : Crane starts unloading container-3 to truck
# 330 : Vessel 2 : Truck returned after transporting container-2
# 330 : Vessel 2 : Truck left with container-3
# 330 : Vessel 1 : Crane starts unloading container-6 to truck
# 333 : Vessel 1 : Truck returned after transporting container-5
# 333 : Vessel 1 : Truck left with container-6
# 333 : Vessel 2 : Crane starts unloading container-4 to truck
# 336 : Vessel 2 : Truck returned after transporting container-3
# 336 : Vessel 2 : Truck left with container-4
# 336 : Vessel 1 : Crane starts unloading container-7 to truck
# 339 : Vessel 1 : Truck returned after transporting container-6
# 339 : Vessel 1 : Truck left with container-7
# 339 : Vessel 2 : Crane starts unloading container-5 to truck
# 342 : Vessel 2 : Truck returned after transporting container-4
# 342 : Vessel 2 : Truck left with container-5
# 342 : Vessel 1 : Crane starts unloading container-8 to truck
# 345 : Vessel 1 : Truck returned after transporting container-7
# 345 : Vessel 1 : Truck left with container-8
# 345 : Vessel 2 : Crane starts unloading container-6 to truck
# 348 : Vessel 2 : Truck returned after transporting container-5
# 348 : Vessel 2 : Truck left with container-6
# 348 : Vessel 1 : Crane starts unloading container-9 to truck
# 351 : Vessel 1 : Truck returned after transporting container-8
# 351 : Vessel 1 : Truck left with container-9
# 351 : Vessel 2 : Crane starts unloading container-7 to truck
# 354 : Vessel 2 : Truck returned after transporting container-6
# 354 : Vessel 2 : Truck left with container-7
# 354 : Vessel 1 : Crane starts unloading container-10 to truck
# 357 : Vessel 1 : Truck returned after transporting container-9
# 357 : Vessel 1 : Truck left with container-10
# 357 : Vessel 2 : Crane starts unloading container-8 to truck
# 360 : Vessel 2 : Truck returned after transporting container-7
# 360 : Vessel 2 : Truck left with container-8
# 360 : Vessel 1 : Crane starts unloading container-11 to truck
# 363 : Vessel 1 : Truck returned after transporting container-10
# 363 : Vessel 1 : Truck left with container-11
# 363 : Vessel 2 : Crane starts unloading container-9 to truck
# 366 : Vessel 2 : Truck returned after transporting container-8
# 366 : Vessel 2 : Truck left with container-9
# 366 : Vessel 1 : Crane starts unloading container-12 to truck
# 369 : Vessel 1 : Truck returned after transporting container-11
# 369 : Vessel 1 : Truck left with container-12
# 369 : Vessel 2 : Crane starts unloading container-10 to truck
# 372 : Vessel 2 : Truck returned after transporting container-9
# 372 : Vessel 2 : Truck left with container-10
# 372 : Vessel 1 : Crane starts unloading container-13 to truck
# 375 : Vessel 1 : Truck returned after transporting container-12
# 375 : Vessel 1 : Truck left with container-13
# 375 : Vessel 2 : Crane starts unloading container-11 to truck
# 378 : Vessel 2 : Truck returned after transporting container-10
# 378 : Vessel 2 : Truck left with container-11
# 378 : Vessel 1 : Crane starts unloading container-14 to truck
# 381 : Vessel 1 : Truck returned after transporting container-13
# 381 : Vessel 1 : Truck left with container-14
# 381 : Vessel 2 : Crane starts unloading container-12 to truck
# 384 : Vessel 2 : Truck returned after transporting container-11
# 384 : Vessel 2 : Truck left with container-12
# 384 : Vessel 1 : Crane starts unloading container-15 to truck
# 387 : Vessel 1 : Truck returned after transporting container-14
# 387 : Vessel 1 : Truck left with container-15
# 387 : Vessel 2 : Crane starts unloading container-13 to truck
# 390 : Vessel 2 : Truck returned after transporting container-12
# 390 : Vessel 2 : Truck left with container-13
# 390 : Vessel 1 : Crane starts unloading container-16 to truck
# 393 : Vessel 1 : Truck returned after transporting container-15
# 393 : Vessel 1 : Truck left with container-16
# 393 : Vessel 2 : Crane starts unloading container-14 to truck
# 396 : Vessel 2 : Truck returned after transporting container-13
# 396 : Vessel 2 : Truck left with container-14
# 396 : Vessel 1 : Crane starts unloading container-17 to truck
# 399 : Vessel 1 : Truck returned after transporting container-16
# 399 : Vessel 1 : Truck left with container-17
# 399 : Vessel 2 : Crane starts unloading container-15 to truck
# 402 : Vessel 2 : Truck returned after transporting container-14
# 402 : Vessel 2 : Truck left with container-15
# 402 : Vessel 1 : Crane starts unloading container-18 to truck
# 405 : Vessel 1 : Truck returned after transporting container-17
# 405 : Vessel 1 : Truck left with container-18
# 405 : Vessel 2 : Crane starts unloading container-16 to truck
# 408 : Vessel 2 : Truck returned after transporting container-15
# 408 : Vessel 2 : Truck left with container-16
# 408 : Vessel 1 : Crane starts unloading container-19 to truck
# 410 : Vessel 3 : Arrived at terminal_ _ _ _ _ _<-\___/
# 411 : Vessel 1 : Truck returned after transporting container-18
# 411 : Vessel 1 : Truck left with container-19
# 411 : Vessel 2 : Crane starts unloading container-17 to truck
# 414 : Vessel 2 : Truck returned after transporting container-16
# 414 : Vessel 2 : Truck left with container-17
# 414 : Vessel 1 : Crane starts unloading container-20 to truck
# 417 : Vessel 1 : Truck returned after transporting container-19
# 417 : Vessel 1 : Truck left with container-20
# 417 : Vessel 2 : Crane starts unloading container-18 to truck
# 420 : Vessel 2 : Truck returned after transporting container-17
# 420 : Vessel 2 : Truck left with container-18
# 420 : Vessel 1 : Crane starts unloading container-21 to truck
# 423 : Vessel 1 : Truck returned after transporting container-20
# 423 : Vessel 1 : Truck left with container-21
# 423 : Vessel 2 : Crane starts unloading container-19 to truck
# 426 : Vessel 2 : Truck returned after transporting container-18
# 426 : Vessel 2 : Truck left with container-19
# 426 : Vessel 1 : Crane starts unloading container-22 to truck
# 429 : Vessel 1 : Truck returned after transporting container-21
# 429 : Vessel 1 : Truck left with container-22
# 429 : Vessel 2 : Crane starts unloading container-20 to truck
# 432 : Vessel 2 : Truck returned after transporting container-19
# 432 : Vessel 2 : Truck left with container-20
# 432 : Vessel 1 : Crane starts unloading container-23 to truck
# 435 : Vessel 1 : Truck returned after transporting container-22
# 435 : Vessel 1 : Truck left with container-23
# 435 : Vessel 2 : Crane starts unloading container-21 to truck
# 438 : Vessel 2 : Truck returned after transporting container-20
# 438 : Vessel 2 : Truck left with container-21
# 438 : Vessel 1 : Crane starts unloading container-24 to truck
# 441 : Vessel 1 : Truck returned after transporting container-23
# 441 : Vessel 1 : Truck left with container-24
# 441 : Vessel 2 : Crane starts unloading container-22 to truck
# 444 : Vessel 2 : Truck returned after transporting container-21
# 444 : Vessel 2 : Truck left with container-22
# 444 : Vessel 1 : Crane starts unloading container-25 to truck
# 447 : Vessel 1 : Truck returned after transporting container-24
# 447 : Vessel 1 : Truck left with container-25
# 447 : Vessel 2 : Crane starts unloading container-23 to truck
# 450 : Vessel 2 : Truck returned after transporting container-22
# 450 : Vessel 2 : Truck left with container-23
# 450 : Vessel 1 : Crane starts unloading container-26 to truck
# 453 : Vessel 1 : Truck returned after transporting container-25
# 453 : Vessel 1 : Truck left with container-26
# 453 : Vessel 2 : Crane starts unloading container-24 to truck
# 456 : Vessel 2 : Truck returned after transporting container-23
# 456 : Vessel 2 : Truck left with container-24
# 456 : Vessel 1 : Crane starts unloading container-27 to truck
# 459 : Vessel 1 : Truck returned after transporting container-26
# 459 : Vessel 1 : Truck left with container-27
# 459 : Vessel 2 : Crane starts unloading container-25 to truck
# 462 : Vessel 2 : Truck returned after transporting container-24
# 462 : Vessel 2 : Truck left with container-25
# 462 : Vessel 1 : Crane starts unloading container-28 to truck
# 465 : Vessel 1 : Truck returned after transporting container-27
# 465 : Vessel 1 : Truck left with container-28
# 465 : Vessel 2 : Crane starts unloading container-26 to truck
# 468 : Vessel 2 : Truck returned after transporting container-25
# 468 : Vessel 2 : Truck left with container-26
# 468 : Vessel 1 : Crane starts unloading container-29 to truck
# 471 : Vessel 1 : Truck returned after transporting container-28
# 471 : Vessel 1 : Truck left with container-29
# 471 : Vessel 2 : Crane starts unloading container-27 to truck
# 474 : Vessel 2 : Truck returned after transporting container-26
# 474 : Vessel 2 : Truck left with container-27
# 474 : Vessel 1 : Crane starts unloading container-30 to truck
# 477 : Vessel 1 : Truck returned after transporting container-29
# 477 : Vessel 1 : Truck left with container-30
# 477 : Vessel 2 : Crane starts unloading container-28 to truck
# 480 : Vessel 2 : Truck returned after transporting container-27
# 480 : Vessel 2 : Truck left with container-28
# 480 : Vessel 1 : Crane starts unloading container-31 to truck
# 483 : Vessel 1 : Truck returned after transporting container-30
# 483 : Vessel 1 : Truck left with container-31
# 483 : Vessel 2 : Crane starts unloading container-29 to truck
# 486 : Vessel 4 : Arrived at terminal_ _ _ _ _ _<-\___/
# 486 : Vessel 2 : Truck returned after transporting container-28
# 486 : Vessel 2 : Truck left with container-29
# 486 : Vessel 1 : Crane starts unloading container-32 to truck
# 489 : Vessel 1 : Truck returned after transporting container-31
# 489 : Vessel 1 : Truck left with container-32
# 489 : Vessel 2 : Crane starts unloading container-30 to truck
# 492 : Vessel 2 : Truck returned after transporting container-29
# 492 : Vessel 2 : Truck left with container-30
# 492 : Vessel 1 : Crane starts unloading container-33 to truck
# 495 : Vessel 1 : Truck returned after transporting container-32
# 495 : Vessel 1 : Truck left with container-33
# 495 : Vessel 2 : Crane starts unloading container-31 to truck
# 498 : Vessel 2 : Truck returned after transporting container-30
# 498 : Vessel 2 : Truck left with container-31
# 498 : Vessel 1 : Crane starts unloading container-34 to truck
# 501 : Vessel 1 : Truck returned after transporting container-33
# 501 : Vessel 1 : Truck left with container-34
# 501 : Vessel 2 : Crane starts unloading container-32 to truck
# 504 : Vessel 2 : Truck returned after transporting container-31
# 504 : Vessel 2 : Truck left with container-32
# 504 : Vessel 1 : Crane starts unloading container-35 to truck
# 507 : Vessel 1 : Truck returned after transporting container-34
# 507 : Vessel 1 : Truck left with container-35
# 507 : Vessel 2 : Crane starts unloading container-33 to truck
# 510 : Vessel 2 : Truck returned after transporting container-32
# 510 : Vessel 2 : Truck left with container-33
# 510 : Vessel 1 : Crane starts unloading container-36 to truck
# 513 : Vessel 1 : Truck returned after transporting container-35
# 513 : Vessel 1 : Truck left with container-36
# 513 : Vessel 2 : Crane starts unloading container-34 to truck
# 516 : Vessel 2 : Truck returned after transporting container-33
# 516 : Vessel 2 : Truck left with container-34
# 516 : Vessel 1 : Crane starts unloading container-37 to truck
# 519 : Vessel 1 : Truck returned after transporting container-36
# 519 : Vessel 1 : Truck left with container-37
# 519 : Vessel 2 : Crane starts unloading container-35 to truck
# 522 : Vessel 2 : Truck returned after transporting container-34
# 522 : Vessel 2 : Truck left with container-35
# 522 : Vessel 1 : Crane starts unloading container-38 to truck
# 525 : Vessel 1 : Truck returned after transporting container-37
# 525 : Vessel 1 : Truck left with container-38
# 525 : Vessel 2 : Crane starts unloading container-36 to truck
# 528 : Vessel 2 : Truck returned after transporting container-35
# 528 : Vessel 2 : Truck left with container-36
# 528 : Vessel 1 : Crane starts unloading container-39 to truck
# 531 : Vessel 1 : Truck returned after transporting container-38
# 531 : Vessel 1 : Truck left with container-39
# 531 : Vessel 2 : Crane starts unloading container-37 to truck
# 534 : Vessel 2 : Truck returned after transporting container-36
# 534 : Vessel 2 : Truck left with container-37
# 534 : Vessel 1 : Crane starts unloading container-40 to truck
# 537 : Vessel 1 : Truck returned after transporting container-39
# 537 : Vessel 1 : Truck left with container-40
# 537 : Vessel 2 : Crane starts unloading container-38 to truck
# 540 : Vessel 2 : Truck returned after transporting container-37
# 540 : Vessel 2 : Truck left with container-38
# 540 : Vessel 1 : Crane starts unloading container-41 to truck
# 543 : Vessel 1 : Truck returned after transporting container-40
# 543 : Vessel 1 : Truck left with container-41
# 543 : Vessel 2 : Crane starts unloading container-39 to truck
# 546 : Vessel 2 : Truck returned after transporting container-38
# 546 : Vessel 2 : Truck left with container-39
# 546 : Vessel 1 : Crane starts unloading container-42 to truck
# 549 : Vessel 1 : Truck returned after transporting container-41
# 549 : Vessel 1 : Truck left with container-42
# 549 : Vessel 2 : Crane starts unloading container-40 to truck
# 552 : Vessel 2 : Truck returned after transporting container-39
# 552 : Vessel 2 : Truck left with container-40
# 552 : Vessel 1 : Crane starts unloading container-43 to truck
# 555 : Vessel 1 : Truck returned after transporting container-42
# 555 : Vessel 1 : Truck left with container-43
# 555 : Vessel 2 : Crane starts unloading container-41 to truck
# 558 : Vessel 2 : Truck returned after transporting container-40
# 558 : Vessel 2 : Truck left with container-41
# 558 : Vessel 1 : Crane starts unloading container-44 to truck
# 561 : Vessel 1 : Truck returned after transporting container-43
# 561 : Vessel 1 : Truck left with container-44
# 561 : Vessel 2 : Crane starts unloading container-42 to truck
# 564 : Vessel 2 : Truck returned after transporting container-41
# 564 : Vessel 2 : Truck left with container-42
# 564 : Vessel 1 : Crane starts unloading container-45 to truck
# 567 : Vessel 1 : Truck returned after transporting container-44
# 567 : Vessel 1 : Truck left with container-45
# 567 : Vessel 2 : Crane starts unloading container-43 to truck
# 570 : Vessel 2 : Truck returned after transporting container-42
# 570 : Vessel 2 : Truck left with container-43
# 570 : Vessel 1 : Crane starts unloading container-46 to truck
# 573 : Vessel 1 : Truck returned after transporting container-45
# 573 : Vessel 1 : Truck left with container-46
# 573 : Vessel 2 : Crane starts unloading container-44 to truck
# 576 : Vessel 2 : Truck returned after transporting container-43
# 576 : Vessel 2 : Truck left with container-44
# 576 : Vessel 1 : Crane starts unloading container-47 to truck
# 579 : Vessel 1 : Truck returned after transporting container-46
# 579 : Vessel 1 : Truck left with container-47
# 579 : Vessel 2 : Crane starts unloading container-45 to truck
# 582 : Vessel 2 : Truck returned after transporting container-44
# 582 : Vessel 2 : Truck left with container-45
# 582 : Vessel 1 : Crane starts unloading container-48 to truck
# 585 : Vessel 1 : Truck returned after transporting container-47
# 585 : Vessel 1 : Truck left with container-48
# 585 : Vessel 2 : Crane starts unloading container-46 to truck
# 588 : Vessel 2 : Truck returned after transporting container-45
# 588 : Vessel 2 : Truck left with container-46
# 588 : Vessel 1 : Crane starts unloading container-49 to truck
# 591 : Vessel 1 : Truck returned after transporting container-48
# 591 : Vessel 1 : Truck left with container-49
# 591 : Vessel 2 : Crane starts unloading container-47 to truck
# 594 : Vessel 2 : Truck returned after transporting container-46
# 594 : Vessel 2 : Truck left with container-47
# 594 : Vessel 1 : Crane starts unloading container-50 to truck
# 597 : Vessel 1 : Truck returned after transporting container-49
# 597 : Vessel 1 : Truck left with container-50
# 597 : Vessel 2 : Crane starts unloading container-48 to truck
# 600 : Vessel 2 : Truck returned after transporting container-47
# 600 : Vessel 2 : Truck left with container-48
# 600 : Vessel 1 : Crane starts unloading container-51 to truck
# 603 : Vessel 1 : Truck returned after transporting container-50
# 603 : Vessel 1 : Truck left with container-51
# 603 : Vessel 2 : Crane starts unloading container-49 to truck
# 606 : Vessel 2 : Truck returned after transporting container-48
# 606 : Vessel 2 : Truck left with container-49
# 606 : Vessel 1 : Crane starts unloading container-52 to truck
# 609 : Vessel 1 : Truck returned after transporting container-51
# 609 : Vessel 1 : Truck left with container-52
# 609 : Vessel 2 : Crane starts unloading container-50 to truck
# 612 : Vessel 2 : Truck returned after transporting container-49
# 612 : Vessel 2 : Truck left with container-50
# 612 : Vessel 1 : Crane starts unloading container-53 to truck
# 615 : Vessel 1 : Truck returned after transporting container-52
# 615 : Vessel 1 : Truck left with container-53
# 615 : Vessel 2 : Crane starts unloading container-51 to truck
# 618 : Vessel 2 : Truck returned after transporting container-50
# 618 : Vessel 2 : Truck left with container-51
# 618 : Vessel 1 : Crane starts unloading container-54 to truck
# 621 : Vessel 1 : Truck returned after transporting container-53
# 621 : Vessel 1 : Truck left with container-54
# 621 : Vessel 2 : Crane starts unloading container-52 to truck
# 624 : Vessel 2 : Truck returned after transporting container-51
# 624 : Vessel 2 : Truck left with container-52
# 624 : Vessel 1 : Crane starts unloading container-55 to truck
# 627 : Vessel 1 : Truck returned after transporting container-54
# 627 : Vessel 1 : Truck left with container-55
# 627 : Vessel 2 : Crane starts unloading container-53 to truck
# 630 : Vessel 2 : Truck returned after transporting container-52
# 630 : Vessel 2 : Truck left with container-53
# 630 : Vessel 1 : Crane starts unloading container-56 to truck
# 633 : Vessel 1 : Truck returned after transporting container-55
# 633 : Vessel 1 : Truck left with container-56
# 633 : Vessel 2 : Crane starts unloading container-54 to truck
# 636 : Vessel 2 : Truck returned after transporting container-53
# 636 : Vessel 2 : Truck left with container-54
# 636 : Vessel 1 : Crane starts unloading container-57 to truck
# 639 : Vessel 1 : Truck returned after transporting container-56
# 639 : Vessel 1 : Truck left with container-57
# 639 : Vessel 2 : Crane starts unloading container-55 to truck
# 642 : Vessel 2 : Truck returned after transporting container-54
# 642 : Vessel 2 : Truck left with container-55
# 642 : Vessel 1 : Crane starts unloading container-58 to truck
# 645 : Vessel 1 : Truck returned after transporting container-57
# 645 : Vessel 1 : Truck left with container-58
# 645 : Vessel 2 : Crane starts unloading container-56 to truck
# 648 : Vessel 2 : Truck returned after transporting container-55
# 648 : Vessel 2 : Truck left with container-56
# 648 : Vessel 1 : Crane starts unloading container-59 to truck
# 651 : Vessel 1 : Truck returned after transporting container-58
# 651 : Vessel 1 : Truck left with container-59
# 651 : Vessel 2 : Crane starts unloading container-57 to truck
# 654 : Vessel 2 : Truck returned after transporting container-56
# 654 : Vessel 2 : Truck left with container-57
# 654 : Vessel 1 : Crane starts unloading container-60 to truck
# 657 : Vessel 1 : Truck returned after transporting container-59
# 657 : Vessel 1 : Truck left with container-60
# 657 : Vessel 2 : Crane starts unloading container-58 to truck
# 660 : Vessel 2 : Truck returned after transporting container-57
# 660 : Vessel 2 : Truck left with container-58
# 660 : Vessel 1 : Crane starts unloading container-61 to truck
# 663 : Vessel 1 : Truck returned after transporting container-60
# 663 : Vessel 1 : Truck left with container-61
# 663 : Vessel 2 : Crane starts unloading container-59 to truck
# 666 : Vessel 2 : Truck returned after transporting container-58
# 666 : Vessel 2 : Truck left with container-59
# 666 : Vessel 1 : Crane starts unloading container-62 to truck
# 669 : Vessel 1 : Truck returned after transporting container-61
# 669 : Vessel 1 : Truck left with container-62
# 669 : Vessel 2 : Crane starts unloading container-60 to truck
# 672 : Vessel 2 : Truck returned after transporting container-59
# 672 : Vessel 2 : Truck left with container-60
# 672 : Vessel 1 : Crane starts unloading container-63 to truck
# 675 : Vessel 1 : Truck returned after transporting container-62
# 675 : Vessel 1 : Truck left with container-63
# 675 : Vessel 2 : Crane starts unloading container-61 to truck
# 678 : Vessel 2 : Truck returned after transporting container-60
# 678 : Vessel 2 : Truck left with container-61
# 678 : Vessel 1 : Crane starts unloading container-64 to truck
# 681 : Vessel 1 : Truck returned after transporting container-63
# 681 : Vessel 1 : Truck left with container-64
# 681 : Vessel 2 : Crane starts unloading container-62 to truck
# 684 : Vessel 2 : Truck returned after transporting container-61
# 684 : Vessel 2 : Truck left with container-62
# 684 : Vessel 1 : Crane starts unloading container-65 to truck
# 687 : Vessel 1 : Truck returned after transporting container-64
# 687 : Vessel 1 : Truck left with container-65
# 687 : Vessel 2 : Crane starts unloading container-63 to truck
# 690 : Vessel 2 : Truck returned after transporting container-62
# 690 : Vessel 2 : Truck left with container-63
# 690 : Vessel 1 : Crane starts unloading container-66 to truck
# 693 : Vessel 1 : Truck returned after transporting container-65
# 693 : Vessel 1 : Truck left with container-66
# 693 : Vessel 2 : Crane starts unloading container-64 to truck
# 696 : Vessel 2 : Truck returned after transporting container-63
# 696 : Vessel 2 : Truck left with container-64
# 696 : Vessel 1 : Crane starts unloading container-67 to truck
# 699 : Vessel 1 : Truck returned after transporting container-66
# 699 : Vessel 1 : Truck left with container-67
# 699 : Vessel 2 : Crane starts unloading container-65 to truck
# 702 : Vessel 2 : Truck returned after transporting container-64
# 702 : Vessel 2 : Truck left with container-65
# 702 : Vessel 1 : Crane starts unloading container-68 to truck
# 705 : Vessel 1 : Truck returned after transporting container-67
# 705 : Vessel 1 : Truck left with container-68
# 705 : Vessel 2 : Crane starts unloading container-66 to truck
# 708 : Vessel 2 : Truck returned after transporting container-65
# 708 : Vessel 2 : Truck left with container-66
# 708 : Vessel 1 : Crane starts unloading container-69 to truck
# 711 : Vessel 1 : Truck returned after transporting container-68
# 711 : Vessel 1 : Truck left with container-69
# 711 : Vessel 2 : Crane starts unloading container-67 to truck
# 714 : Vessel 2 : Truck returned after transporting container-66
# 714 : Vessel 2 : Truck left with container-67
# 714 : Vessel 1 : Crane starts unloading container-70 to truck
# 717 : Vessel 1 : Truck returned after transporting container-69
# 717 : Vessel 1 : Truck left with container-70
# 717 : Vessel 2 : Crane starts unloading container-68 to truck
# 720 : Vessel 2 : Truck returned after transporting container-67
# 720 : Vessel 2 : Truck left with container-68
# 720 : Vessel 1 : Crane starts unloading container-71 to truck
# 723 : Vessel 1 : Truck returned after transporting container-70
# 723 : Vessel 1 : Truck left with container-71
# 723 : Vessel 2 : Crane starts unloading container-69 to truck
# 726 : Vessel 2 : Truck returned after transporting container-68
# 726 : Vessel 2 : Truck left with container-69
# 726 : Vessel 1 : Crane starts unloading container-72 to truck
# 729 : Vessel 1 : Truck returned after transporting container-71
# 729 : Vessel 1 : Truck left with container-72
# 729 : Vessel 2 : Crane starts unloading container-70 to truck
# 732 : Vessel 2 : Truck returned after transporting container-69
# 732 : Vessel 2 : Truck left with container-70
# 732 : Vessel 1 : Crane starts unloading container-73 to truck
# 735 : Vessel 1 : Truck returned after transporting container-72
# 735 : Vessel 1 : Truck left with container-73
# 735 : Vessel 2 : Crane starts unloading container-71 to truck
# 738 : Vessel 2 : Truck returned after transporting container-70
# 738 : Vessel 2 : Truck left with container-71
# 738 : Vessel 1 : Crane starts unloading container-74 to truck
# 741 : Vessel 1 : Truck returned after transporting container-73
# 741 : Vessel 1 : Truck left with container-74
# 741 : Vessel 2 : Crane starts unloading container-72 to truck
# 744 : Vessel 2 : Truck returned after transporting container-71
# 744 : Vessel 2 : Truck left with container-72
# 744 : Vessel 1 : Crane starts unloading container-75 to truck
# 747 : Vessel 1 : Truck returned after transporting container-74
# 747 : Vessel 1 : Truck left with container-75
# 747 : Vessel 2 : Crane starts unloading container-73 to truck
# 750 : Vessel 2 : Truck returned after transporting container-72
# 750 : Vessel 2 : Truck left with container-73
# 750 : Vessel 1 : Crane starts unloading container-76 to truck
# 753 : Vessel 1 : Truck returned after transporting container-75
# 753 : Vessel 1 : Truck left with container-76
# 753 : Vessel 2 : Crane starts unloading container-74 to truck
# 756 : Vessel 2 : Truck returned after transporting container-73
# 756 : Vessel 2 : Truck left with container-74
# 756 : Vessel 1 : Crane starts unloading container-77 to truck
# 759 : Vessel 1 : Truck returned after transporting container-76
# 759 : Vessel 1 : Truck left with container-77
# 759 : Vessel 2 : Crane starts unloading container-75 to truck
# 762 : Vessel 2 : Truck returned after transporting container-74
# 762 : Vessel 2 : Truck left with container-75
# 762 : Vessel 1 : Crane starts unloading container-78 to truck
# 765 : Vessel 1 : Truck returned after transporting container-77
# 765 : Vessel 1 : Truck left with container-78
# 765 : Vessel 2 : Crane starts unloading container-76 to truck
# 768 : Vessel 2 : Truck returned after transporting container-75
# 768 : Vessel 2 : Truck left with container-76
# 768 : Vessel 1 : Crane starts unloading container-79 to truck
# 771 : Vessel 1 : Truck returned after transporting container-78
# 771 : Vessel 1 : Truck left with container-79
# 771 : Vessel 2 : Crane starts unloading container-77 to truck
# 774 : Vessel 2 : Truck returned after transporting container-76
# 774 : Vessel 2 : Truck left with container-77
# 774 : Vessel 1 : Crane starts unloading container-80 to truck
# 777 : Vessel 1 : Truck returned after transporting container-79
# 777 : Vessel 1 : Truck left with container-80
# 777 : Vessel 2 : Crane starts unloading container-78 to truck
# 780 : Vessel 2 : Truck returned after transporting container-77
# 780 : Vessel 2 : Truck left with container-78
# 780 : Vessel 1 : Crane starts unloading container-81 to truck
# 783 : Vessel 1 : Truck returned after transporting container-80
# 783 : Vessel 1 : Truck left with container-81
# 783 : Vessel 2 : Crane starts unloading container-79 to truck
# 786 : Vessel 2 : Truck returned after transporting container-78
# 786 : Vessel 2 : Truck left with container-79
# 786 : Vessel 1 : Crane starts unloading container-82 to truck
# 789 : Vessel 1 : Truck returned after transporting container-81
# 789 : Vessel 1 : Truck left with container-82
# 789 : Vessel 2 : Crane starts unloading container-80 to truck
# 792 : Vessel 2 : Truck returned after transporting container-79
# 792 : Vessel 2 : Truck left with container-80
# 792 : Vessel 1 : Crane starts unloading container-83 to truck
# 795 : Vessel 1 : Truck returned after transporting container-82
# 795 : Vessel 1 : Truck left with container-83
# 795 : Vessel 2 : Crane starts unloading container-81 to truck
# 798 : Vessel 2 : Truck returned after transporting container-80
# 798 : Vessel 2 : Truck left with container-81
# 798 : Vessel 1 : Crane starts unloading container-84 to truck
# 801 : Vessel 1 : Truck returned after transporting container-83
# 801 : Vessel 1 : Truck left with container-84
# 801 : Vessel 2 : Crane starts unloading container-82 to truck
# 804 : Vessel 2 : Truck returned after transporting container-81
# 804 : Vessel 2 : Truck left with container-82
# 804 : Vessel 1 : Crane starts unloading container-85 to truck
# 807 : Vessel 1 : Truck returned after transporting container-84
# 807 : Vessel 1 : Truck left with container-85
# 807 : Vessel 2 : Crane starts unloading container-83 to truck
# 810 : Vessel 2 : Truck returned after transporting container-82
# 810 : Vessel 2 : Truck left with container-83
# 810 : Vessel 1 : Crane starts unloading container-86 to truck
# 813 : Vessel 1 : Truck returned after transporting container-85
# 813 : Vessel 1 : Truck left with container-86
# 813 : Vessel 2 : Crane starts unloading container-84 to truck
# 816 : Vessel 2 : Truck returned after transporting container-83
# 816 : Vessel 2 : Truck left with container-84
# 816 : Vessel 1 : Crane starts unloading container-87 to truck
# 819 : Vessel 1 : Truck returned after transporting container-86
# 819 : Vessel 1 : Truck left with container-87
# 819 : Vessel 2 : Crane starts unloading container-85 to truck
# 822 : Vessel 2 : Truck returned after transporting container-84
# 822 : Vessel 2 : Truck left with container-85
# 822 : Vessel 1 : Crane starts unloading container-88 to truck
# 825 : Vessel 1 : Truck returned after transporting container-87
# 825 : Vessel 1 : Truck left with container-88
# 825 : Vessel 2 : Crane starts unloading container-86 to truck
# 828 : Vessel 2 : Truck returned after transporting container-85
# 828 : Vessel 2 : Truck left with container-86
# 828 : Vessel 1 : Crane starts unloading container-89 to truck
# 831 : Vessel 1 : Truck returned after transporting container-88
# 831 : Vessel 1 : Truck left with container-89
# 831 : Vessel 2 : Crane starts unloading container-87 to truck
# 834 : Vessel 2 : Truck returned after transporting container-86
# 834 : Vessel 2 : Truck left with container-87
# 834 : Vessel 1 : Crane starts unloading container-90 to truck
# 837 : Vessel 1 : Truck returned after transporting container-89
# 837 : Vessel 1 : Truck left with container-90
# 837 : Vessel 2 : Crane starts unloading container-88 to truck
# 840 : Vessel 2 : Truck returned after transporting container-87
# 840 : Vessel 2 : Truck left with container-88
# 840 : Vessel 1 : Crane starts unloading container-91 to truck
# 843 : Vessel 1 : Truck returned after transporting container-90
# 843 : Vessel 1 : Truck left with container-91
# 843 : Vessel 2 : Crane starts unloading container-89 to truck
# 846 : Vessel 2 : Truck returned after transporting container-88
# 846 : Vessel 2 : Truck left with container-89
# 846 : Vessel 1 : Crane starts unloading container-92 to truck
# 849 : Vessel 1 : Truck returned after transporting container-91
# 849 : Vessel 1 : Truck left with container-92
# 849 : Vessel 2 : Crane starts unloading container-90 to truck
# 852 : Vessel 2 : Truck returned after transporting container-89
# 852 : Vessel 2 : Truck left with container-90
# 852 : Vessel 1 : Crane starts unloading container-93 to truck
# 855 : Vessel 1 : Truck returned after transporting container-92
# 855 : Vessel 1 : Truck left with container-93
# 855 : Vessel 2 : Crane starts unloading container-91 to truck
# 858 : Vessel 2 : Truck returned after transporting container-90
# 858 : Vessel 2 : Truck left with container-91
# 858 : Vessel 1 : Crane starts unloading container-94 to truck
# 861 : Vessel 1 : Truck returned after transporting container-93
# 861 : Vessel 1 : Truck left with container-94
# 861 : Vessel 2 : Crane starts unloading container-92 to truck
# 864 : Vessel 2 : Truck returned after transporting container-91
# 864 : Vessel 2 : Truck left with container-92
# 864 : Vessel 1 : Crane starts unloading container-95 to truck
# 867 : Vessel 1 : Truck returned after transporting container-94
# 867 : Vessel 1 : Truck left with container-95
# 867 : Vessel 2 : Crane starts unloading container-93 to truck
# 870 : Vessel 2 : Truck returned after transporting container-92
# 870 : Vessel 2 : Truck left with container-93
# 870 : Vessel 1 : Crane starts unloading container-96 to truck
# 873 : Vessel 1 : Truck returned after transporting container-95
# 873 : Vessel 1 : Truck left with container-96
# 873 : Vessel 2 : Crane starts unloading container-94 to truck
# 876 : Vessel 2 : Truck returned after transporting container-93
# 876 : Vessel 2 : Truck left with container-94
# 876 : Vessel 1 : Crane starts unloading container-97 to truck
# 879 : Vessel 1 : Truck returned after transporting container-96
# 879 : Vessel 1 : Truck left with container-97
# 879 : Vessel 2 : Crane starts unloading container-95 to truck
# 882 : Vessel 2 : Truck returned after transporting container-94
# 882 : Vessel 2 : Truck left with container-95
# 882 : Vessel 1 : Crane starts unloading container-98 to truck
# 885 : Vessel 1 : Truck returned after transporting container-97
# 885 : Vessel 1 : Truck left with container-98
# 885 : Vessel 2 : Crane starts unloading container-96 to truck
# 886 : Vessel 5 : Arrived at terminal_ _ _ _ _ _<-\___/
# 888 : Vessel 2 : Truck returned after transporting container-95
# 888 : Vessel 2 : Truck left with container-96
# 888 : Vessel 1 : Crane starts unloading container-99 to truck
# 891 : Vessel 1 : Truck returned after transporting container-98
# 891 : Vessel 1 : Truck left with container-99
# 891 : Vessel 2 : Crane starts unloading container-97 to truck
# 894 : Vessel 2 : Truck returned after transporting container-96
# 894 : Vessel 2 : Truck left with container-97
# 894 : Vessel 1 : Crane starts unloading container-100 to truck
# 897 : Vessel 1 : Truck returned after transporting container-99
# 897 : Vessel 1 : Truck left with container-100
# 897 : Vessel 2 : Crane starts unloading container-98 to truck
# 900 : Vessel 2 : Truck returned after transporting container-97
# 900 : Vessel 2 : Truck left with container-98
# 900 : Vessel 1 : Crane starts unloading container-101 to truck
# 903 : Vessel 1 : Truck returned after transporting container-100
# 903 : Vessel 1 : Truck left with container-101
# 903 : Vessel 2 : Crane starts unloading container-99 to truck
# 906 : Vessel 2 : Truck returned after transporting container-98
# 906 : Vessel 2 : Truck left with container-99
# 906 : Vessel 1 : Crane starts unloading container-102 to truck
# 909 : Vessel 1 : Truck returned after transporting container-101
# 909 : Vessel 1 : Truck left with container-102
# 909 : Vessel 2 : Crane starts unloading container-100 to truck
# 912 : Vessel 2 : Truck returned after transporting container-99
# 912 : Vessel 2 : Truck left with container-100
# 912 : Vessel 1 : Crane starts unloading container-103 to truck
# 915 : Vessel 1 : Truck returned after transporting container-102
# 915 : Vessel 1 : Truck left with container-103
# 915 : Vessel 2 : Crane starts unloading container-101 to truck
# 918 : Vessel 2 : Truck returned after transporting container-100
# 918 : Vessel 2 : Truck left with container-101
# 918 : Vessel 1 : Crane starts unloading container-104 to truck
# 921 : Vessel 1 : Truck returned after transporting container-103
# 921 : Vessel 1 : Truck left with container-104
# 921 : Vessel 2 : Crane starts unloading container-102 to truck
# 924 : Vessel 2 : Truck returned after transporting container-101
# 924 : Vessel 2 : Truck left with container-102
# 924 : Vessel 1 : Crane starts unloading container-105 to truck
# 927 : Vessel 1 : Truck returned after transporting container-104
# 927 : Vessel 1 : Truck left with container-105
# 927 : Vessel 2 : Crane starts unloading container-103 to truck
# 930 : Vessel 2 : Truck returned after transporting container-102
# 930 : Vessel 2 : Truck left with container-103
# 930 : Vessel 1 : Crane starts unloading container-106 to truck
# 933 : Vessel 1 : Truck returned after transporting container-105
# 933 : Vessel 1 : Truck left with container-106
# 933 : Vessel 2 : Crane starts unloading container-104 to truck
# 936 : Vessel 2 : Truck returned after transporting container-103
# 936 : Vessel 2 : Truck left with container-104
# 936 : Vessel 1 : Crane starts unloading container-107 to truck
# 939 : Vessel 1 : Truck returned after transporting container-106
# 939 : Vessel 1 : Truck left with container-107
# 939 : Vessel 2 : Crane starts unloading container-105 to truck
# 942 : Vessel 2 : Truck returned after transporting container-104
# 942 : Vessel 2 : Truck left with container-105
# 942 : Vessel 1 : Crane starts unloading container-108 to truck
# 945 : Vessel 1 : Truck returned after transporting container-107
# 945 : Vessel 1 : Truck left with container-108
# 945 : Vessel 2 : Crane starts unloading container-106 to truck
# 948 : Vessel 2 : Truck returned after transporting container-105
# 948 : Vessel 2 : Truck left with container-106
# 948 : Vessel 1 : Crane starts unloading container-109 to truck
# 951 : Vessel 1 : Truck returned after transporting container-108
# 951 : Vessel 1 : Truck left with container-109
# 951 : Vessel 2 : Crane starts unloading container-107 to truck
# 954 : Vessel 2 : Truck returned after transporting container-106
# 954 : Vessel 2 : Truck left with container-107
# 954 : Vessel 1 : Crane starts unloading container-110 to truck
# 957 : Vessel 1 : Truck returned after transporting container-109
# 957 : Vessel 1 : Truck left with container-110
# 957 : Vessel 2 : Crane starts unloading container-108 to truck
# 960 : Vessel 2 : Truck returned after transporting container-107
# 960 : Vessel 2 : Truck left with container-108
# 960 : Vessel 1 : Crane starts unloading container-111 to truck
# 963 : Vessel 1 : Truck returned after transporting container-110
# 963 : Vessel 1 : Truck left with container-111
# 963 : Vessel 2 : Crane starts unloading container-109 to truck
# 966 : Vessel 2 : Truck returned after transporting container-108
# 966 : Vessel 2 : Truck left with container-109
# 966 : Vessel 1 : Crane starts unloading container-112 to truck
# 969 : Vessel 1 : Truck returned after transporting container-111
# 969 : Vessel 1 : Truck left with container-112
# 969 : Vessel 2 : Crane starts unloading container-110 to truck
# 972 : Vessel 2 : Truck returned after transporting container-109
# 972 : Vessel 2 : Truck left with container-110
# 972 : Vessel 1 : Crane starts unloading container-113 to truck
# 975 : Vessel 1 : Truck returned after transporting container-112
# 975 : Vessel 1 : Truck left with container-113
# 975 : Vessel 2 : Crane starts unloading container-111 to truck
# 978 : Vessel 2 : Truck returned after transporting container-110
# 978 : Vessel 2 : Truck left with container-111
# 978 : Vessel 1 : Crane starts unloading container-114 to truck
# 981 : Vessel 1 : Truck returned after transporting container-113
# 981 : Vessel 1 : Truck left with container-114
# 981 : Vessel 2 : Crane starts unloading container-112 to truck
# 984 : Vessel 2 : Truck returned after transporting container-111
# 984 : Vessel 2 : Truck left with container-112
# 984 : Vessel 1 : Crane starts unloading container-115 to truck
# 987 : Vessel 1 : Truck returned after transporting container-114
# 987 : Vessel 1 : Truck left with container-115
# 987 : Vessel 2 : Crane starts unloading container-113 to truck
# 990 : Vessel 2 : Truck returned after transporting container-112
# 990 : Vessel 2 : Truck left with container-113
# 990 : Vessel 1 : Crane starts unloading container-116 to truck
# 993 : Vessel 1 : Truck returned after transporting container-115
# 993 : Vessel 1 : Truck left with container-116
# 993 : Vessel 2 : Crane starts unloading container-114 to truck
# 996 : Vessel 2 : Truck returned after transporting container-113
# 996 : Vessel 2 : Truck left with container-114
# 996 : Vessel 1 : Crane starts unloading container-117 to truck
# 999 : Vessel 1 : Truck returned after transporting container-116
# 999 : Vessel 1 : Truck left with container-117
# 999 : Vessel 2 : Crane starts unloading container-115 to truck
# 1002 : Vessel 2 : Truck returned after transporting container-114
# 1002 : Vessel 2 : Truck left with container-115
# 1002 : Vessel 1 : Crane starts unloading container-118 to truck
# 1005 : Vessel 1 : Truck returned after transporting container-117
# 1005 : Vessel 1 : Truck left with container-118
# 1005 : Vessel 2 : Crane starts unloading container-116 to truck
# 1008 : Vessel 2 : Truck returned after transporting container-115
# 1008 : Vessel 2 : Truck left with container-116
# 1008 : Vessel 1 : Crane starts unloading container-119 to truck
# 1011 : Vessel 1 : Truck returned after transporting container-118
# 1011 : Vessel 1 : Truck left with container-119
# 1011 : Vessel 2 : Crane starts unloading container-117 to truck
# 1014 : Vessel 2 : Truck returned after transporting container-116
# 1014 : Vessel 2 : Truck left with container-117
# 1014 : Vessel 1 : Crane starts unloading container-120 to truck
# 1017 : Vessel 1 : Truck returned after transporting container-119
# 1017 : Vessel 1 : Truck left with container-120
# 1017 : Vessel 2 : Crane starts unloading container-118 to truck
# 1020 : Vessel 2 : Truck returned after transporting container-117
# 1020 : Vessel 2 : Truck left with container-118
# 1020 : Vessel 1 : Crane starts unloading container-121 to truck
# 1023 : Vessel 1 : Truck returned after transporting container-120
# 1023 : Vessel 1 : Truck left with container-121
# 1023 : Vessel 2 : Crane starts unloading container-119 to truck
# 1026 : Vessel 2 : Truck returned after transporting container-118
# 1026 : Vessel 2 : Truck left with container-119
# 1026 : Vessel 1 : Crane starts unloading container-122 to truck
# 1029 : Vessel 1 : Truck returned after transporting container-121
# 1029 : Vessel 1 : Truck left with container-122
# 1029 : Vessel 2 : Crane starts unloading container-120 to truck
# 1032 : Vessel 2 : Truck returned after transporting container-119
# 1032 : Vessel 2 : Truck left with container-120
# 1032 : Vessel 1 : Crane starts unloading container-123 to truck
# 1035 : Vessel 1 : Truck returned after transporting container-122
# 1035 : Vessel 1 : Truck left with container-123
# 1035 : Vessel 2 : Crane starts unloading container-121 to truck
# 1038 : Vessel 2 : Truck returned after transporting container-120
# 1038 : Vessel 2 : Truck left with container-121
# 1038 : Vessel 1 : Crane starts unloading container-124 to truck
# 1041 : Vessel 1 : Truck returned after transporting container-123
# 1041 : Vessel 1 : Truck left with container-124
# 1041 : Vessel 2 : Crane starts unloading container-122 to truck
# 1044 : Vessel 2 : Truck returned after transporting container-121
# 1044 : Vessel 2 : Truck left with container-122
# 1044 : Vessel 1 : Crane starts unloading container-125 to truck
# 1047 : Vessel 1 : Truck returned after transporting container-124
# 1047 : Vessel 1 : Truck left with container-125
# 1047 : Vessel 2 : Crane starts unloading container-123 to truck
# 1050 : Vessel 2 : Truck returned after transporting container-122
# 1050 : Vessel 2 : Truck left with container-123
# 1050 : Vessel 1 : Crane starts unloading container-126 to truck
# 1053 : Vessel 1 : Truck returned after transporting container-125
# 1053 : Vessel 1 : Truck left with container-126
# 1053 : Vessel 2 : Crane starts unloading container-124 to truck
# 1056 : Vessel 2 : Truck returned after transporting container-123
# 1056 : Vessel 2 : Truck left with container-124
# 1056 : Vessel 1 : Crane starts unloading container-127 to truck
# 1059 : Vessel 1 : Truck returned after transporting container-126
# 1059 : Vessel 1 : Truck left with container-127
# 1059 : Vessel 2 : Crane starts unloading container-125 to truck
# 1062 : Vessel 2 : Truck returned after transporting container-124
# 1062 : Vessel 2 : Truck left with container-125
# 1062 : Vessel 1 : Crane starts unloading container-128 to truck
# 1065 : Vessel 1 : Truck returned after transporting container-127
# 1065 : Vessel 1 : Truck left with container-128
# 1065 : Vessel 2 : Crane starts unloading container-126 to truck
# 1068 : Vessel 2 : Truck returned after transporting container-125
# 1068 : Vessel 2 : Truck left with container-126
# 1068 : Vessel 1 : Crane starts unloading container-129 to truck
# 1071 : Vessel 1 : Truck returned after transporting container-128
# 1071 : Vessel 1 : Truck left with container-129
# 1071 : Vessel 2 : Crane starts unloading container-127 to truck
# 1074 : Vessel 2 : Truck returned after transporting container-126
# 1074 : Vessel 2 : Truck left with container-127
# 1074 : Vessel 1 : Crane starts unloading container-130 to truck
# 1077 : Vessel 1 : Truck returned after transporting container-129
# 1077 : Vessel 1 : Truck left with container-130
# 1077 : Vessel 2 : Crane starts unloading container-128 to truck
# 1080 : Vessel 2 : Truck returned after transporting container-127
# 1080 : Vessel 2 : Truck left with container-128
# 1080 : Vessel 1 : Crane starts unloading container-131 to truck
# 1083 : Vessel 1 : Truck returned after transporting container-130
# 1083 : Vessel 1 : Truck left with container-131
# 1083 : Vessel 2 : Crane starts unloading container-129 to truck
# 1086 : Vessel 2 : Truck returned after transporting container-128
# 1086 : Vessel 2 : Truck left with container-129
# 1086 : Vessel 1 : Crane starts unloading container-132 to truck
# 1089 : Vessel 1 : Truck returned after transporting container-131
# 1089 : Vessel 1 : Truck left with container-132
# 1089 : Vessel 2 : Crane starts unloading container-130 to truck
# 1092 : Vessel 2 : Truck returned after transporting container-129
# 1092 : Vessel 2 : Truck left with container-130
# 1092 : Vessel 1 : Crane starts unloading container-133 to truck
# 1095 : Vessel 1 : Truck returned after transporting container-132
# 1095 : Vessel 1 : Truck left with container-133
# 1095 : Vessel 2 : Crane starts unloading container-131 to truck
# 1098 : Vessel 2 : Truck returned after transporting container-130
# 1098 : Vessel 2 : Truck left with container-131
# 1098 : Vessel 1 : Crane starts unloading container-134 to truck
# 1101 : Vessel 1 : Truck returned after transporting container-133
# 1101 : Vessel 1 : Truck left with container-134
# 1101 : Vessel 2 : Crane starts unloading container-132 to truck
# 1104 : Vessel 2 : Truck returned after transporting container-131
# 1104 : Vessel 2 : Truck left with container-132
# 1104 : Vessel 1 : Crane starts unloading container-135 to truck
# 1107 : Vessel 1 : Truck returned after transporting container-134
# 1107 : Vessel 1 : Truck left with container-135
# 1107 : Vessel 2 : Crane starts unloading container-133 to truck
# 1110 : Vessel 2 : Truck returned after transporting container-132
# 1110 : Vessel 2 : Truck left with container-133
# 1110 : Vessel 1 : Crane starts unloading container-136 to truck
# 1113 : Vessel 1 : Truck returned after transporting container-135
# 1113 : Vessel 1 : Truck left with container-136
# 1113 : Vessel 2 : Crane starts unloading container-134 to truck
# 1116 : Vessel 2 : Truck returned after transporting container-133
# 1116 : Vessel 2 : Truck left with container-134
# 1116 : Vessel 1 : Crane starts unloading container-137 to truck
# 1119 : Vessel 1 : Truck returned after transporting container-136
# 1119 : Vessel 1 : Truck left with container-137
# 1119 : Vessel 2 : Crane starts unloading container-135 to truck
# 1122 : Vessel 2 : Truck returned after transporting container-134
# 1122 : Vessel 2 : Truck left with container-135
# 1122 : Vessel 1 : Crane starts unloading container-138 to truck
# 1125 : Vessel 1 : Truck returned after transporting container-137
# 1125 : Vessel 1 : Truck left with container-138
# 1125 : Vessel 2 : Crane starts unloading container-136 to truck
# 1128 : Vessel 2 : Truck returned after transporting container-135
# 1128 : Vessel 2 : Truck left with container-136
# 1128 : Vessel 1 : Crane starts unloading container-139 to truck
# 1131 : Vessel 1 : Truck returned after transporting container-138
# 1131 : Vessel 1 : Truck left with container-139
# ...
# 2733 : Vessel 5 : Truck returned after transporting container-105
# 2733 : Vessel 5 : Truck left with container-106
# 2733 : Vessel 6 : Crane starts unloading container-104 to truck
# 2736 : Vessel 6 : Truck returned after transporting container-103
# 2736 : Vessel 6 : Truck left with container-104
# 2736 : Vessel 5 : Crane starts unloading container-107 to truck
# 2739 : Vessel 5 : Truck returned after transporting container-106
# 2739 : Vessel 5 : Truck left with container-107
# 2739 : Vessel 6 : Crane starts unloading container-105 to truck
# 2742 : Vessel 6 : Truck returned after transporting container-104
# 2742 : Vessel 6 : Truck left with container-105
# 2742 : Vessel 5 : Crane starts unloading container-108 to truck
# 2745 : Vessel 5 : Truck returned after transporting container-107
# 2745 : Vessel 5 : Truck left with container-108
# 2745 : Vessel 6 : Crane starts unloading container-106 to truck
# 2748 : Vessel 6 : Truck returned after transporting container-105
# 2748 : Vessel 6 : Truck left with container-106
# 2748 : Vessel 5 : Crane starts unloading container-109 to truck
# 2751 : Vessel 5 : Truck returned after transporting container-108
# 2751 : Vessel 5 : Truck left with container-109
# 2751 : Vessel 6 : Crane starts unloading container-107 to truck
# 2754 : Vessel 6 : Truck returned after transporting container-106
# 2754 : Vessel 6 : Truck left with container-107
# 2754 : Vessel 5 : Crane starts unloading container-110 to truck
# 2757 : Vessel 5 : Truck returned after transporting container-109
# 2757 : Vessel 5 : Truck left with container-110
# 2757 : Vessel 6 : Crane starts unloading container-108 to truck
# 2760 : Vessel 6 : Truck returned after transporting container-107
# 2760 : Vessel 6 : Truck left with container-108
# 2760 : Vessel 5 : Crane starts unloading container-111 to truck
# 2763 : Vessel 5 : Truck returned after transporting container-110
# 2763 : Vessel 5 : Truck left with container-111
# 2763 : Vessel 6 : Crane starts unloading container-109 to truck
# 2766 : Vessel 6 : Truck returned after transporting container-108
# 2766 : Vessel 6 : Truck left with container-109
# 2766 : Vessel 5 : Crane starts unloading container-112 to truck
# 2768 : Vessel 15 : Arrived at terminal_ _ _ _ _ _<-\___/
# 2769 : Vessel 5 : Truck returned after transporting container-111
# 2769 : Vessel 5 : Truck left with container-112
# 2769 : Vessel 6 : Crane starts unloading container-110 to truck
# 2772 : Vessel 6 : Truck returned after transporting container-109
# 2772 : Vessel 6 : Truck left with container-110
# 2772 : Vessel 5 : Crane starts unloading container-113 to truck
# 2775 : Vessel 5 : Truck returned after transporting container-112
# 2775 : Vessel 5 : Truck left with container-113
# 2775 : Vessel 6 : Crane starts unloading container-111 to truck
# 2778 : Vessel 6 : Truck returned after transporting container-110
# 2778 : Vessel 6 : Truck left with container-111
# 2778 : Vessel 5 : Crane starts unloading container-114 to truck
# 2781 : Vessel 5 : Truck returned after transporting container-113
# 2781 : Vessel 5 : Truck left with container-114
# 2781 : Vessel 6 : Crane starts unloading container-112 to truck
# 2784 : Vessel 6 : Truck returned after transporting container-111
# 2784 : Vessel 6 : Truck left with container-112
# 2784 : Vessel 5 : Crane starts unloading container-115 to truck
# 2787 : Vessel 5 : Truck returned after transporting container-114
# 2787 : Vessel 5 : Truck left with container-115
# 2787 : Vessel 6 : Crane starts unloading container-113 to truck
# 2790 : Vessel 6 : Truck returned after transporting container-112
# 2790 : Vessel 6 : Truck left with container-113
# 2790 : Vessel 5 : Crane starts unloading container-116 to truck
# 2793 : Vessel 5 : Truck returned after transporting container-115
# 2793 : Vessel 5 : Truck left with container-116
# 2793 : Vessel 6 : Crane starts unloading container-114 to truck
# 2796 : Vessel 6 : Truck returned after transporting container-113
# 2796 : Vessel 6 : Truck left with container-114
# 2796 : Vessel 5 : Crane starts unloading container-117 to truck
# 2799 : Vessel 5 : Truck returned after transporting container-116
# 2799 : Vessel 5 : Truck left with container-117
# 2799 : Vessel 6 : Crane starts unloading container-115 to truck
# 2802 : Vessel 6 : Truck returned after transporting container-114
# 2802 : Vessel 6 : Truck left with container-115
# 2802 : Vessel 5 : Crane starts unloading container-118 to truck
# 2805 : Vessel 5 : Truck returned after transporting container-117
# 2805 : Vessel 5 : Truck left with container-118
# 2805 : Vessel 6 : Crane starts unloading container-116 to truck
# 2808 : Vessel 6 : Truck returned after transporting container-115
# 2808 : Vessel 6 : Truck left with container-116
# 2808 : Vessel 5 : Crane starts unloading container-119 to truck
# 2811 : Vessel 5 : Truck returned after transporting container-118
# 2811 : Vessel 5 : Truck left with container-119
# 2811 : Vessel 6 : Crane starts unloading container-117 to truck
# 2814 : Vessel 6 : Truck returned after transporting container-116
# 2814 : Vessel 6 : Truck left with container-117
# 2814 : Vessel 5 : Crane starts unloading container-120 to truck
# 2817 : Vessel 5 : Truck returned after transporting container-119
# 2817 : Vessel 5 : Truck left with container-120
# 2817 : Vessel 6 : Crane starts unloading container-118 to truck
# 2820 : Vessel 6 : Truck returned after transporting container-117
# 2820 : Vessel 6 : Truck left with container-118
# 2820 : Vessel 5 : Crane starts unloading container-121 to truck
# 2823 : Vessel 5 : Truck returned after transporting container-120
# 2823 : Vessel 5 : Truck left with container-121
# 2823 : Vessel 6 : Crane starts unloading container-119 to truck
# 2826 : Vessel 6 : Truck returned after transporting container-118
# 2826 : Vessel 6 : Truck left with container-119
# 2826 : Vessel 5 : Crane starts unloading container-122 to truck
# 2829 : Vessel 5 : Truck returned after transporting container-121
# 2829 : Vessel 5 : Truck left with container-122
# 2829 : Vessel 6 : Crane starts unloading container-120 to truck
# 2832 : Vessel 6 : Truck returned after transporting container-119
# 2832 : Vessel 6 : Truck left with container-120
# 2832 : Vessel 5 : Crane starts unloading container-123 to truck
# 2835 : Vessel 5 : Truck returned after transporting container-122
# 2835 : Vessel 5 : Truck left with container-123
# 2835 : Vessel 6 : Crane starts unloading container-121 to truck
# 2838 : Vessel 6 : Truck returned after transporting container-120
# 2838 : Vessel 6 : Truck left with container-121
# 2838 : Vessel 5 : Crane starts unloading container-124 to truck
# 2841 : Vessel 5 : Truck returned after transporting container-123
# 2841 : Vessel 5 : Truck left with container-124
# 2841 : Vessel 6 : Crane starts unloading container-122 to truck
# 2844 : Vessel 6 : Truck returned after transporting container-121
# 2844 : Vessel 6 : Truck left with container-122
# 2844 : Vessel 5 : Crane starts unloading container-125 to truck
# 2847 : Vessel 5 : Truck returned after transporting container-124
# 2847 : Vessel 5 : Truck left with container-125
# 2847 : Vessel 6 : Crane starts unloading container-123 to truck
# 2850 : Vessel 6 : Truck returned after transporting container-122
# 2850 : Vessel 6 : Truck left with container-123
# 2850 : Vessel 5 : Crane starts unloading container-126 to truck
# 2853 : Vessel 5 : Truck returned after transporting container-125
# 2853 : Vessel 5 : Truck left with container-126
# 2853 : Vessel 6 : Crane starts unloading container-124 to truck
# 2856 : Vessel 6 : Truck returned after transporting container-123
# 2856 : Vessel 6 : Truck left with container-124
# 2856 : Vessel 5 : Crane starts unloading container-127 to truck
# 2859 : Vessel 5 : Truck returned after transporting container-126
# 2859 : Vessel 5 : Truck left with container-127
# 2859 : Vessel 6 : Crane starts unloading container-125 to truck
# 2862 : Vessel 6 : Truck returned after transporting container-124
# 2862 : Vessel 6 : Truck left with container-125
# 2862 : Vessel 5 : Crane starts unloading container-128 to truck
# 2865 : Vessel 5 : Truck returned after transporting container-127
# 2865 : Vessel 5 : Truck left with container-128
# 2865 : Vessel 6 : Crane starts unloading container-126 to truck
# 2868 : Vessel 6 : Truck returned after transporting container-125
# 2868 : Vessel 6 : Truck left with container-126
# 2868 : Vessel 5 : Crane starts unloading container-129 to truck
# 2871 : Vessel 5 : Truck returned after transporting container-128
# 2871 : Vessel 5 : Truck left with container-129
# 2871 : Vessel 6 : Crane starts unloading container-127 to truck
# 2874 : Vessel 6 : Truck returned after transporting container-126
# 2874 : Vessel 6 : Truck left with container-127
# 2874 : Vessel 5 : Crane starts unloading container-130 to truck
# 2877 : Vessel 5 : Truck returned after transporting container-129
# 2877 : Vessel 5 : Truck left with container-130
# 2877 : Vessel 6 : Crane starts unloading container-128 to truck
# 2880 : Vessel 6 : Truck returned after transporting container-127
# 2880 : Vessel 6 : Truck left with container-128
# 2880 : Vessel 5 : Crane starts unloading container-131 to truck
# 2883 : Vessel 5 : Truck returned after transporting container-130
# 2883 : Vessel 5 : Truck left with container-131
# 2883 : Vessel 6 : Crane starts unloading container-129 to truck
# 2886 : Vessel 6 : Truck returned after transporting container-128
# 2886 : Vessel 6 : Truck left with container-129
# 2886 : Vessel 5 : Crane starts unloading container-132 to truck
# 2889 : Vessel 5 : Truck returned after transporting container-131
# 2889 : Vessel 5 : Truck left with container-132
# 2889 : Vessel 6 : Crane starts unloading container-130 to truck
# 2892 : Vessel 6 : Truck returned after transporting container-129
# 2892 : Vessel 6 : Truck left with container-130
# 2892 : Vessel 5 : Crane starts unloading container-133 to truck
# 2895 : Vessel 5 : Truck returned after transporting container-132
# 2895 : Vessel 5 : Truck left with container-133
# 2895 : Vessel 6 : Crane starts unloading container-131 to truck
# 2898 : Vessel 6 : Truck returned after transporting container-130
# 2898 : Vessel 6 : Truck left with container-131
# 2898 : Vessel 5 : Crane starts unloading container-134 to truck
# 2901 : Vessel 5 : Truck returned after transporting container-133
# 2901 : Vessel 5 : Truck left with container-134
# 2901 : Vessel 6 : Crane starts unloading container-132 to truck
# 2904 : Vessel 6 : Truck returned after transporting container-131
# 2904 : Vessel 6 : Truck left with container-132
# 2904 : Vessel 5 : Crane starts unloading container-135 to truck
# 2907 : Vessel 5 : Truck returned after transporting container-134
# 2907 : Vessel 5 : Truck left with container-135
# 2907 : Vessel 6 : Crane starts unloading container-133 to truck
# 2910 : Vessel 6 : Truck returned after transporting container-132
# 2910 : Vessel 6 : Truck left with container-133
# 2910 : Vessel 5 : Crane starts unloading container-136 to truck
# 2913 : Vessel 5 : Truck returned after transporting container-135
# 2913 : Vessel 5 : Truck left with container-136
# 2913 : Vessel 6 : Crane starts unloading container-134 to truck
# 2916 : Vessel 6 : Truck returned after transporting container-133
# 2916 : Vessel 6 : Truck left with container-134
# 2916 : Vessel 5 : Crane starts unloading container-137 to truck
# 2919 : Vessel 5 : Truck returned after transporting container-136
# 2919 : Vessel 5 : Truck left with container-137
# 2919 : Vessel 6 : Crane starts unloading container-135 to truck
# 2922 : Vessel 6 : Truck returned after transporting container-134
# 2922 : Vessel 6 : Truck left with container-135
# 2922 : Vessel 5 : Crane starts unloading container-138 to truck
# 2925 : Vessel 5 : Truck returned after transporting container-137
# 2925 : Vessel 5 : Truck left with container-138
# 2925 : Vessel 6 : Crane starts unloading container-136 to truck
# 2928 : Vessel 6 : Truck returned after transporting container-135
# 2928 : Vessel 6 : Truck left with container-136
# 2928 : Vessel 5 : Crane starts unloading container-139 to truck
# 2931 : Vessel 5 : Truck returned after transporting container-138
# 2931 : Vessel 5 : Truck left with container-139
# 2931 : Vessel 6 : Crane starts unloading container-137 to truck
# 2934 : Vessel 6 : Truck returned after transporting container-136
# 2934 : Vessel 6 : Truck left with container-137
# 2934 : Vessel 5 : Crane starts unloading container-140 to truck
# 2937 : Vessel 5 : Truck returned after transporting container-139
# 2937 : Vessel 5 : Truck left with container-140
# 2937 : Vessel 6 : Crane starts unloading container-138 to truck
# 2940 : Vessel 6 : Truck returned after transporting container-137
# 2940 : Vessel 6 : Truck left with container-138
# 2940 : Vessel 5 : Crane starts unloading container-141 to truck
# 2943 : Vessel 5 : Truck returned after transporting container-140
# 2943 : Vessel 5 : Truck left with container-141
# 2943 : Vessel 6 : Crane starts unloading container-139 to truck
# 2946 : Vessel 6 : Truck returned after transporting container-138
# 2946 : Vessel 6 : Truck left with container-139
# 2946 : Vessel 5 : Crane starts unloading container-142 to truck
# 2949 : Vessel 5 : Truck returned after transporting container-141
# 2949 : Vessel 5 : Truck left with container-142
# 2949 : Vessel 6 : Crane starts unloading container-140 to truck
# 2952 : Vessel 6 : Truck returned after transporting container-139
# 2952 : Vessel 6 : Truck left with container-140
# 2952 : Vessel 5 : Crane starts unloading container-143 to truck
# 2955 : Vessel 5 : Truck returned after transporting container-142
# 2955 : Vessel 5 : Truck left with container-143
# 2955 : Vessel 6 : Crane starts unloading container-141 to truck
# 2958 : Vessel 6 : Truck returned after transporting container-140
# 2958 : Vessel 6 : Truck left with container-141
# 2958 : Vessel 5 : Crane starts unloading container-144 to truck
# 2961 : Vessel 5 : Truck returned after transporting container-143
# 2961 : Vessel 5 : Truck left with container-144
# 2961 : Vessel 6 : Crane starts unloading container-142 to truck
# 2964 : Vessel 6 : Truck returned after transporting container-141
# 2964 : Vessel 6 : Truck left with container-142
# 2964 : Vessel 5 : Crane starts unloading container-145 to truck
# 2967 : Vessel 5 : Truck returned after transporting container-144
# 2967 : Vessel 5 : Truck left with container-145
# 2967 : Vessel 6 : Crane starts unloading container-143 to truck
# 2970 : Vessel 6 : Truck returned after transporting container-142
# 2970 : Vessel 6 : Truck left with container-143
# 2970 : Vessel 5 : Crane starts unloading container-146 to truck
# 2973 : Vessel 5 : Truck returned after transporting container-145
# 2973 : Vessel 5 : Truck left with container-146
# 2973 : Vessel 6 : Crane starts unloading container-144 to truck
# 2976 : Vessel 6 : Truck returned after transporting container-143
# 2976 : Vessel 6 : Truck left with container-144
# 2976 : Vessel 5 : Crane starts unloading container-147 to truck
# 2979 : Vessel 5 : Truck returned after transporting container-146
# 2979 : Vessel 5 : Truck left with container-147
# 2979 : Vessel 6 : Crane starts unloading container-145 to truck
# 2982 : Vessel 6 : Truck returned after transporting container-144
# 2982 : Vessel 6 : Truck left with container-145
# 2982 : Vessel 5 : Crane starts unloading container-148 to truck
# 2985 : Vessel 5 : Truck returned after transporting container-147
# 2985 : Vessel 5 : Truck left with container-148
# 2985 : Vessel 6 : Crane starts unloading container-146 to truck
# 2988 : Vessel 6 : Truck returned after transporting container-145
# 2988 : Vessel 6 : Truck left with container-146
# 2988 : Vessel 5 : Crane starts unloading container-149 to truck
# 2991 : Vessel 5 : Truck returned after transporting container-148
# 2991 : Vessel 5 : Truck left with container-149
# 2991 : Vessel 6 : Crane starts unloading container-147 to truck
# 2994 : Vessel 6 : Truck returned after transporting container-146
# 2994 : Vessel 6 : Truck left with container-147
# 2994 : Vessel 5 : Crane starts unloading container-150 to truck
# 2997 : Vessel 5 : Truck returned after transporting container-149
# 2997 : Vessel 5 : Truck left with container-150
# 2997 : Vessel 5 : Finished unloading and is leaving_ _ _ _ _ \___/->
# 2997 : Vessel 6 : Crane starts unloading container-148 to truck
# 2997 : Vessel 7 : Berthed
